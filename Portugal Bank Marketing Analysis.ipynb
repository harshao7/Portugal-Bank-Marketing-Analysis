# %% [markdown]
# #  Portugal Bank Marketing Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bank.csv',sep = ';')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %% [markdown]
# #####  In our dataset there are 41188 rows and 21 columns/features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 36951   45       admin.   married    university.degree       no      no   no
# ...

# %%
df[df.duplicated()]
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 36951   45       admin.   married    university.degree       no      no   no
# ...

# %%
df[df.duplicated()].count()
# Out:
# age               12
# job               12
# marital           12
# education         12
# default           12
# housing           12
# loan              12
# contact           12
# month             12
# day_of_week       12
# duration          12
# campaign          12
# pdays             12
# previous          12
# poutcome          12
# emp.var.rate      12
# cons.price.idx    12
# cons.conf.idx     12
# euribor3m         12
# nr.employed       12
# y                 12
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41176 entries, 0 to 41175
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  object
#  2   marital         41176 non-null  object
#  3   education       41176 non-null  object
#  4   default         41176 non-null  object
#  5   housing         41176 non-null  object
#  6   loan            41176 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  object
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
df.describe(include='O')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41176    41176              41176   41176   41176  41176     41176
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10419    24921              12164   32577   21571  33938     26135
#
#         month day_of_week     poutcome      y
# count   41176       41176        41176  41176
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13767        8618        35551  36537

# %%
categorical = df.select_dtypes('O')
categorical
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41171      retired  married  professional.course       no     yes   no
# 41172  blue-collar  married  professional.course       no      no   no
# 41173      retired  married    university.degree       no     yes   no
# 41174   technician  married  professional.course       no      no   no
# 41175      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome    y
# 0      telephone   may         mon  nonexistent   no
# ...

# %%
contineous = df.select_dtypes(include=np.number)

# %%
contineous
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41171   73       334         1    999         0          -1.1          94.767
# 41172   46       383         1    999         0          -1.1          94.767
# 41173   56       189         2    999         0          -1.1          94.767
# 41174   44       442         1    999         0          -1.1          94.767
# 41175   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
for value_count in categorical:
    print(categorical[value_count].value_counts(),'\n\n')
# Out:
# admin.           10419
# blue-collar       9253
# technician        6739
# services          3967
# management        2924
# retired           1718
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64
#
#
# married     24921
# single      11564
# divorced     4611
# unknown        80
# Name: marital, dtype: int64
#
#
# university.degree      12164
# high.school             9512
# basic.9y                6045
# professional.course     5240
# basic.4y                4176
# basic.6y                2291
# unknown                 1730
# illiterate                18
# Name: education, dtype: int64
#
#
# no         32577
# unknown     8596
# yes            3
# Name: default, dtype: int64
#
#
# yes        21571
# no         18615
# unknown      990
# Name: housing, dtype: int64
#
#
# no         33938
# yes         6248
# unknown      990
# Name: loan, dtype: int64
#
#
# ...

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
for count_plot in categorical.columns:
    ax=sns.countplot(df[count_plot])
    plt.title(count_plot)
    plt.xticks(rotation=90)
    plt.show()

# %%
for pie_plot in categorical.columns:
    plt.figure(figsize=(18,12))
    plt.pie(df[pie_plot].value_counts().values, labels=df[pie_plot].value_counts().index, autopct='%1.2f%%')
    plt.show()

# %% [markdown]
# ## primary analysis of categorical variable
#
# * Top 3 bank clints are working in an Admin, blue-collar and technicians domain.
# * ~60% of bank clints are married.
# * ~51% bank clints are holding university degree.
# * ~1.8% bank clints holds the default credit card.
# * ~46% of bank clints are having house loan.
# * ~16% of the bank clints are having personal loan.
# * ~74% bank clints were connected through cellular.
# * ~58% of bank clints were connected in the month of may,jul and august.
# * outcome of the previous marketing campaign says that nonexistent clints were there during the visit.

# %% [markdown]
# #  EDA

# %% [markdown]
# ###  Missing Values:

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data=df.isnull(),cmap='gist_heat_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #####  There are no missing values either any special charecters

# %% [markdown]
# #  Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for column in categorical:
    df[column]= le.fit_transform(df[column])

# %%
df.head(10)
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
# 5   45    7        1          2        1        0     0        1      6
# 6   59    0        1          5        0        0     0        1      6
# 7   41    1        1          7        1        0     0        1      6
# 8   24    9        2          5        0        2     0        1      6
# 9   25    7        2          3        0        2     0        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# ...

# %% [markdown]
# # Selecting important features based on Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# %%
X= df.drop('y',axis=1)
X
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        1        0     0        1      6
# 2       37    7        1          3        0        2     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41171   73    5        1          5        0        2     0        0      7
# 41172   46    1        1          5        0        0     0        0      7
# 41173   56    5        1          6        0        2     0        0      7
# 41174   44    9        1          5        0        0     0        0      7
# 41175   74    5        1          5        0        2     0        0      7
#
# ...

# %%
y = df['y']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41171    1
# 41172    0
# 41173    0
# 41174    1
# 41175    0
# Name: y, Length: 41176, dtype: int32

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (28823, 20)

# %%
X_test.shape
# Out:
# (12353, 20)

# %%
y_test.shape
# Out:
# (12353,)

# %%
FSRF = SelectFromModel(RandomForestClassifier(n_estimators=100))
FSRF.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
FSRF.get_support()
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#         True,  True])

# %%
get_features = X_train.columns[(FSRF.get_support())]

# %%
print(get_features)
# Out:
# Index(['age', 'duration', 'euribor3m', 'nr.employed'], dtype='object')

# %% [markdown]
# #  Handling unbalanced data using SMOTE

# %%
from imblearn.over_sampling import SMOTE
sm= SMOTE(random_state=1)

# %%
sns.countplot(df['y'])
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %%
sm_x,sm_y=sm.fit_resample(X_train,y_train)

# %%
sns.countplot(sm_y)
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %% [markdown]
# #  Standardize the data using the anyone of the scalers provided by sklearn

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %%
models = {
    LogisticRegression(random_state=1):'Logistic Regression',
    SVC(probability=True):"Support Vector Machine",
    RandomForestClassifier():'Random Forest',
    KNeighborsClassifier(n_neighbors=10): "KNN",
    GaussianNB(): "Naïve Bayes",
    AdaBoostClassifier(n_estimators=100, random_state=0):"AdaBoost"
    }
for m in models.keys():
    m.fit(X_train,y_train)
for model,name in models.items():
     print(f"Accuracy Score for {name} is : ",model.score(X_test,y_test)*100,"%")
# Out:
# Accuracy Score for Logistic Regression is :  91.08718529911762 %
# Accuracy Score for Support Vector Machine is :  91.04670930138428 %
# Accuracy Score for Random Forest is :  91.40289808143771 %
# Accuracy Score for KNN is :  90.45575973447745 %
# Accuracy Score for Naïve Bayes is :  84.51388326722254 %
# Accuracy Score for AdaBoost is :  91.08718529911762 %

# %% [markdown]
# ###### Ignoring Randomforest Classifier algorithm;
# ## KNN classifier shows the better model performance

# %%
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion matrix for {type(model).__name__}:")
    print(cm)
# Out:
# Confusion matrix for LogisticRegression:
# [[10651   316]
#  [  785   601]]
# Confusion matrix for SVC:
# [[10689   278]
#  [  828   558]]
# Confusion matrix for RandomForestClassifier:
# [[10564   403]
#  [  660   726]]
# Confusion matrix for KNeighborsClassifier:
# [[10736   231]
#  [  948   438]]
# Confusion matrix for GaussianNB:
# [[9611 1356]
#  [ 557  829]]
# Confusion matrix for AdaBoostClassifier:
# [[10660   307]
#  [  794   592]]

# %%
for model, name in models.items():
    y_pred = model.predict(X_test)
    print(f"Results for {name}:")
    print(classification_report(y_test, y_pred))
# Out:
# Results for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10967
#            1       0.66      0.43      0.52      1386
#
#     accuracy                           0.91     12353
#    macro avg       0.79      0.70      0.74     12353
# weighted avg       0.90      0.91      0.90     12353
#
# Results for Support Vector Machine:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10967
#            1       0.67      0.40      0.50      1386
#
#     accuracy                           0.91     12353
#    macro avg       0.80      0.69      0.73     12353
# weighted avg       0.90      0.91      0.90     12353
#
# Results for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     10967
#            1       0.64      0.52      0.58      1386
#
# ...

# %%
for model in models:
#     model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy of", type(model).__name__, "is", accuracy)
# Out:
# Accuracy of LogisticRegression is 0.9108718529911762
# Accuracy of SVC is 0.9104670930138428
# Accuracy of RandomForestClassifier is 0.9139480288189104
# Accuracy of KNeighborsClassifier is 0.9045575973447746
# Accuracy of GaussianNB is 0.8451388326722253
# Accuracy of AdaBoostClassifier is 0.9108718529911762

# %% [markdown]
# ###### Ignoring Randomforest Classifier algorithm;
# ## LogisticRegression classifier shows the better model performance

# %%
auc_scores = []
roc_curves = []
for model in models:
    y_pred = model.predict_proba(X_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    roc_curves.append((fpr, tpr))
    auc_scores.append(roc_auc_score(y_test, y_pred))
plt.figure(figsize=(8,8))
for i, roc_curve in enumerate(roc_curves):
    plt.plot(roc_curve[0], roc_curve[1], label=f'Model {i+1} (AUC={auc_scores[i]:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
model_accuracy = {'LoR': 0.93, 'SVC': 0.91, 'RF': 0.94, 'KNN': 0.89, 'NB': 0.86, 'AdaBoost': 0.94}
df = pd.DataFrame.from_dict(model_accuracy, orient='index', columns=['Accuracy'])
df = df.sort_values(by=['Accuracy'], ascending=False)
print(df)
# Out:
#           Accuracy
# RF            0.94
# AdaBoost      0.94
# LoR           0.93
# SVC           0.91
# KNN           0.89
# NB            0.86

# %% [markdown]
# ###### Ignoring Randomforest Classifier algorithm;
# ## AdaBoost classifier shows the better model performance

# %%
# List of accuracy values for each model
accuracies = [0.93, 0.91, 0.94, 0.89, 0.86,0.94]

# List of model names
models = ['LoR', 'SVC', 'RF', 'KNN', 'NB', 'AdaBoost']

# Plot the accuracies
plt.plot(models, accuracies, 'bo-')

# Set the title and labels for the plot
plt.title('Accuracy Comparison')
plt.xlabel('Models')
plt.ylabel('Accuracy')

# Show the plot
plt.show()

# %%
data = {'Model': models, 'Accuracy': accuracies}

# %%
df = pd.DataFrame(data)

# %%
sns.barplot(x='Model', y='Accuracy', data=df)
plt.ylim(0, 1) # Set the y-axis limit to be between 0 and 1
plt.show() # Show the plot

# %%
# Define classifiers with their hyperparameters
classifiers = [("GaussianNB", GaussianNB(), {}), 
               ("Decision Tree", DecisionTreeClassifier(random_state=42), {'max_depth': [5, 10, 15], 'min_samples_split': [2, 5, 10]}), 
               ("K-Nearest Neighbors", KNeighborsClassifier(), {'n_neighbors': [3, 5, 7, 9]}), 
               ("Logistic Regression", LogisticRegression(random_state=42), {'C': [0.1, 1, 10], 'penalty': ['l1', 'l2']})]

# Perform hyperparameter tuning for each classifier and print the results
for name, clf, param_grid in classifiers:
    grid_search = GridSearchCV(clf, param_grid, cv=5)
    grid_search.fit(X, y)
    print(name, "best parameters:", grid_search.best_params_)
    print(name, "best score:", grid_search.best_score_)

# %%
# Define classifiers with their hyperparameters
classifiers = [("GaussianNB", GaussianNB(), {}), 
               ("Decision Tree", DecisionTreeClassifier(random_state=42), {'max_depth': [5, 10, 15], 'min_samples_split': [2, 5, 10]}), 
               ("K-Nearest Neighbors", KNeighborsClassifier(), {'n_neighbors': [3, 5, 7, 9]}), 
               ("Logistic Regression", LogisticRegression(random_state=42), {'C': [0.1, 1, 10], 'penalty': ['l1', 'l2']}),
               ("Random Forest", RandomForestClassifier(random_state=42), {'n_estimators': [50, 100, 150, 200], 'max_depth': [5, 10, 15], 'min_samples_split': [2, 5, 10]}),
               ("AdaBoost", AdaBoostClassifier(random_state=42), {'n_estimators': [50, 100, 150, 200], 'learning_rate': [0.1, 0.5, 1]})]

# Perform hyperparameter tuning for each classifier using randomized search and nested cross-validation
for name, clf, param_dist in classifiers:
    random_search = RandomizedSearchCV(clf, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
    scores = cross_val_score(random_search, X, y, cv=5)
    print(name, "scores:", scores)
    print(name, "mean score:", scores.mean())
    print(name, "standard deviation:", scores.std())
    print(name, "best parameters:", random_search.best_params_)
    print(name, "best score:", random_search.best_score_)

# %% [markdown]
# # Part II: Time Series

# %% [markdown]
# # Q1. Get the modal price of onion for each month for the Mumbai market (Hint: set monthly date as index and drop redundant columns)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import adfuller

# %%
MWMA = pd.read_csv('MonthWiseMarketArrivals_Clean.csv')

# %%
MWMA.sample(10)
# Out:
#                     market      month  year  quantity  priceMin  priceMax  \
# date
# 2010-07-01        GUWAHATI       July  2010     36250      1066      1300
# 2012-10-01       BANGALORE    October  2012   1098253       479      1203
# 2013-06-01      ABOHAR(PB)       June  2013      1645       853      1297
# 2010-09-01     MAHUVA(GUJ)  September  2010     15806       574      1354
# 2013-08-01      KALVAN(MS)     August  2013     45717      2000      4215
# 2011-12-01      KANPUR(UP)   December  2011      4250       729       771
# 2013-07-01     SOLAPUR(MS)       July  2013     88931       440      2543
# 2015-02-01  BHUBNESWER(OR)   February  2015     26650      1998      2120
# 2014-09-01    JODHPUR(RAJ)  September  2014     18155       797      1487
# 2011-12-01      SURAT(GUJ)   December  2011     51800       470       815
#
#             priceMod state        city
# date
# 2010-07-01      1209   ASM    GUWAHATI
# 2012-10-01       987   KNT   BANGALORE
# ...

# %%
MWMA.shape
# Out:
# (10227, 10)

# %%
MWMA.date = pd.DatetimeIndex(MWMA.date)

# %%
MWMA = MWMA.set_index('date')

# %%
MWMA = MWMA.sort_values(by = 'date')

# %%
MWMA.head()
# Out:
#                    market     month  year  quantity  priceMin  priceMax  \
# date
# 1996-01-01  LASALGAON(MS)   January  1996    225063       160       257
# 1996-02-01  LASALGAON(MS)  February  1996    196164       133       229
# 1996-03-01  LASALGAON(MS)     March  1996    178992       155       274
# 1996-04-01  LASALGAON(MS)     April  1996    192592       136       279
# 1996-05-01  LASALGAON(MS)       May  1996    237574       154       312
#
#             priceMod state       city
# date
# 1996-01-01       226    MS  LASALGAON
# 1996-02-01       186    MS  LASALGAON
# 1996-03-01       243    MS  LASALGAON
# 1996-04-01       254    MS  LASALGAON
# 1996-05-01       269    MS  LASALGAON

# %%
MWMA_Mumbai = MWMA.loc[MWMA.city == 'MUMBAI'].copy()

# %%
MWMA_Mumbai.head()
# Out:
#             market     month  year  quantity  priceMin  priceMax  priceMod  \
# date
# 2004-01-01  MUMBAI   January  2004    267100       719       971       849
# 2004-02-01  MUMBAI  February  2004    239350       614       834       736
# 2004-03-01  MUMBAI     March  2004    238000       436       557       498
# 2004-04-01  MUMBAI     April  2004    198200       346       475       397
# 2004-05-01  MUMBAI       May  2004    166430       357       466       405
#
#            state    city
# date
# 2004-01-01    MS  MUMBAI
# 2004-02-01    MS  MUMBAI
# 2004-03-01    MS  MUMBAI
# 2004-04-01    MS  MUMBAI
# 2004-05-01    MS  MUMBAI

# %%
MWMA_Mumbai = MWMA_Mumbai.drop(['market', 'month', 'year', 'priceMin', 'priceMax', 'state', 'city'], axis = 1)

# %%
MWMA_Mumbai.head()
# Out:
#             quantity  priceMod
# date
# 2004-01-01    267100       849
# 2004-02-01    239350       736
# 2004-03-01    238000       498
# 2004-04-01    198200       397
# 2004-05-01    166430       405

# %%
MWMA_Mumbai.priceMod.plot()
plt.show()

# %%
MWMA_Mumbai.quantity.plot()
plt.show()

# %%
MWMA_Mumbai.priceMod.plot(kind = 'hist', bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
MWMA_Mumbai['log_priceMod'] = np.log(MWMA_Mumbai.priceMod)
MWMA_Mumbai.log_priceMod.plot(kind = 'hist', bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
MWMA_Mumbai.log_priceMod.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
MWMA_Mumbai_MEAN = Mar_On_blr.log_priceMod.mean()
MWMA_Mumbai['mean_price'] = np.exp(MWMA_Mumbai_MEAN)
MWMA_Mumbai.head()
# Out:
#             quantity  priceMod  log_priceMod  mean_price
# date
# 2004-01-01    267100       849      6.744059  884.565812
# 2004-02-01    239350       736      6.601230  884.565812
# 2004-03-01    238000       498      6.210600  884.565812
# 2004-04-01    198200       397      5.983936  884.565812
# 2004-05-01    166430       405      6.003887  884.565812

# %% [markdown]
# # Q2. Build time series model and check the performance of the model using RMSE

# %%
Mar_On_price = pd.DataFrame(MWMA['priceMod'].resample('M').sum())
Mar_On_price
# Out:
#             priceMod
# date
# 1996-01-31       226
# 1996-02-29       186
# 1996-03-31       243
# 1996-04-30       254
# 1996-05-31       269
# ...              ...
# 2015-10-31    255491
# 2015-11-30    186994
# 2015-12-31    132759
# 2016-01-31     98476
# 2016-02-29     75034
#
# [242 rows x 1 columns]

# %%
# Plot

plt.plot(Mar_On_price, 'r')
plt.xticks(rotation = 45)
plt.title('Monthlywise Price Data')
plt.xlabel('Months')
plt.ylabel('Price Value')
plt.show()

# %%
# Decompose with multiplicative model

from statsmodels.tsa.seasonal import seasonal_decompose

Mar_On_price_dec_m = seasonal_decompose(Mar_On_price, model = 'mul')
Mar_On_price_dec_m.plot();

# %% [markdown]
# ## Trend & seasonal can be observed

# %%
# Test for stationarity

from statsmodels.tsa.stattools import adfuller

Mar_On_price_adf = adfuller(Mar_On_price)

# %%
print('ADF Statistic : %f' % Mar_On_price_adf[0])
print('p-value : %f' % Mar_On_price_adf[1])
print('Critical Values : ')
for key, value in Mar_On_price_adf[4].items():
    print('\t%s : %.3f' % (key, value))
# Out:
# ADF Statistic : -0.079602
# p-value : 0.951433
# Critical Values :
# 	1% : -3.459
# 	5% : -2.874
# 	10% : -2.574

# %%
pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Applying auto arima method for prediction
import pmdarima 
from pmdarima import auto_arima
Price_AutoArima = auto_arima(Mar_On_price)
Price_AutoArima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  242
# Model:               SARIMAX(3, 1, 2)   Log Likelihood               -2678.389
# Date:                Tue, 28 Feb 2023   AIC                           5368.778
# Time:                        12:28:03   BIC                           5389.687
# Sample:                    01-31-1996   HQIC                          5377.202
#                          - 02-29-2016
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4032      0.081      4.953      0.000       0.244       0.563
# ar.L2          0.5377      0.055      9.764      0.000       0.430       0.646
# ar.L3         -0.4956      0.045    -10.950      0.000      -0.584      -0.407
# ...

# %%
Mar_On_price_aa_v = pd.DataFrame(Price_AutoArima.predict_in_sample(), index = Mar_On_price.index)
Mar_On_price_aa_v
# Out:
#             predicted_mean
# date
# 1996-01-31        0.000000
# 1996-02-29      329.139978
# 1996-03-31       91.531037
# 1996-04-30      252.599631
# 1996-05-31      195.849129
# ...                    ...
# 2015-10-31   337179.830396
# 2015-11-30   153017.946742
# 2015-12-31   139828.306792
# 2016-01-31   103930.422340
# 2016-02-29    95381.459931
#
# [242 rows x 1 columns]

# %%
Mar_On_price_aa_v.plot()
plt.title('Line plot of Residuals')
# Out:
# Text(0.5, 1.0, 'Line plot of Residuals')

# %%
Mar_On_price_aa_v.plot(kind = 'hist')
plt.title('Histogram of Residuals')
# Out:
# Text(0.5, 1.0, 'Histogram of Residuals')

# %%
Mar_On_price_aa_v.plot(kind = 'kde')
plt.title('Density plot of Residuals')
# Out:
# Text(0.5, 1.0, 'Density plot of Residuals')

# %%
Mar_On_se = pow(Mar_On_price_aa_v, 2)
Mar_On_se.head()
# Out:
#             predicted_mean
# date
# 1996-01-31        0.000000
# 1996-02-29   108333.125317
# 1996-03-31     8377.930694
# 1996-04-30    63806.573437
# 1996-05-31    38356.881181

# %%
from math import sqrt
Mar_On_mse = (Mar_On_se.sum())/len(Mar_On_se)
Mar_On_mse
# Out:
# predicted_mean    4.230687e+09
# dtype: float64

# %%
Mar_On_rmse = sqrt(Mar_On_mse)
print(Mar_On_rmse)
# Out:
# 65043.72868317235

# %%
plt.plot(Mar_On_price)
plt.plot(Mar_On_price_aa_v, 'g')
plt.plot(Mar_On_price_aa_v, 'r')
plt.legend(['Actual', 'Model Values', 'Residuals'], bbox_to_anchor = (1, 1)) 
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Q3. Plot ACF and PACF plots

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_acf(Mar_On_price_aa_v, lags = 20);

# %%
plot_pacf(Mar_On_price_aa_v, lags = 20)

# %% [markdown]
# #  Q4. Exponential smoothing using Holt-Winter’s technique and Forecast onion price for Mumbai marke

# %%
# Model with triple exponential smoothing
# applicable when trend and seasonality exists

from statsmodels.tsa.holtwinters import ExponentialSmoothing

Mar_On_Exp_Sm = ExponentialSmoothing(Mar_On_price, seasonal_periods = 12, trend = 'add', seasonal = 'add').fit()
Mar_On_Exp_Sm.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:                 priceMod   No. Observations:                  242
# Model:             ExponentialSmoothing   SSE                   102764494275.009
# Optimized:                         True   AIC                           4839.758
# Trend:                         Additive   BIC                           4895.581
# Seasonal:                      Additive   AICC                          4842.825
# Seasonal Periods:                    12   Date:                 Tue, 28 Feb 2023
# Box-Cox:                          False   Time:                         12:56:31
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ...

# %% [markdown]
# #

# %%
# Residual given by the model

Mar_On_res1 = pd.DataFrame(Mar_On_Exp_Sm.resid)
Mar_On_res1.head()
# Out:
#                      0
# date
# 1996-01-31   72.171733
# 1996-02-29  540.683917
# 1996-03-31  959.274764
# 1996-04-30  126.220187
# 1996-05-31 -284.978478

# %%
Mar_On_res1.plot()
plt.title('Line plot of Residuals')
# Out:
# Text(0.5, 1.0, 'Line plot of Residuals')

# %% [markdown]
# #

# %%
# Squaring resiuals / errors

Mar_On_se1 = pow(Mar_On_res1, 2)
Mar_On_se1.head()
# Out:
#                         0
# date
# 1996-01-31    5208.759038
# 1996-02-29  292339.098618
# 1996-03-31  920208.072238
# 1996-04-30   15931.535541
# 1996-05-31   81212.733143

# %%
# avearge / mean of Squaring residuals / errors

Mar_On_mse1 = (Mar_On_se1.sum()) / len(Mar_On_se1)
print(Mar_On_mse1)
# Out:
# 0    4.246467e+08
# dtype: float64

# %%
# Root of average / mean of Squaring residuals / errors

Mar_On_rmse1 = sqrt(Mar_On_mse1)
Mar_On_rmse1
# Out:
# 20606.956848547226

# %% [markdown]
# #

# %%
# foresting / predicting

Mar_On_pred2 = Mar_On_Exp_Sm.forecast(steps = 19)
Mar_On_pred2
# Out:
# 2016-03-31    74094.713459
# 2016-04-30    74458.854503
# 2016-05-31    75025.454884
# 2016-06-30    75810.051598
# 2016-07-31    76943.371949
# 2016-08-31    78557.342526
# 2016-09-30    79498.033820
# 2016-10-31    79721.760609
# 2016-11-30    77674.954553
# 2016-12-31    76120.757314
# 2017-01-31    76251.867516
# 2017-02-28    75424.628208
# 2017-03-31    74372.256611
# 2017-04-30    74736.397655
# 2017-05-31    75302.998036
# 2017-06-30    76087.594750
# 2017-07-31    77220.915102
# 2017-08-31    78834.885679
# 2017-09-30    79775.576972
# Freq: M, dtype: float64

# %% [markdown]
# #

# %%
# Plot actual and forecast

plt.plot(Mar_On_price, color = 'm')
plt.plot(Mar_On_pred2, color = 'g')
plt.legend(['Actual', 'Forest - ExponentialSmoothing'], bbox_to_anchor = (1, 1), loc = 4)
plt.show()

# %% [markdown]
# #

# %%
# Plot actual, forecast & residuals

plt.plot(Mar_On_price)
plt.plot(Mar_On_Exp_Sm.fittedvalues, 'g')
plt.plot(Mar_On_res1, 'r')
plt.legend(['Actual', 'Model Values', 'Residuals'])
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #

# %%
#_______________Applying auto - arima to forecast

from pmdarima import auto_arima

Mar_On_price_mode = auto_arima(Mar_On_price)
Mar_On_price_mode.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  242
# Model:               SARIMAX(3, 1, 2)   Log Likelihood               -2678.389
# Date:                Tue, 28 Feb 2023   AIC                           5368.778
# Time:                        12:57:03   BIC                           5389.687
# Sample:                    01-31-1996   HQIC                          5377.202
#                          - 02-29-2016
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4032      0.081      4.953      0.000       0.244       0.563
# ar.L2          0.5377      0.055      9.764      0.000       0.430       0.646
# ar.L3         -0.4956      0.045    -10.950      0.000      -0.584      -0.407
# ...

# %% [markdown]
# #

# %%
# Residual given by the model 

Mar_On_price_mode_res = Mar_On_price_mode.resid()
Mar_On_price_mode_res
# Out:
# date
# 1996-01-31      226.000000
# 1996-02-29     -143.139978
# 1996-03-31      151.468963
# 1996-04-30        1.400369
# 1996-05-31       73.150871
#                   ...
# 2015-10-31   -81688.830396
# 2015-11-30    33976.053258
# 2015-12-31    -7069.306792
# 2016-01-31    -5454.422340
# 2016-02-29   -20347.459931
# Freq: M, Length: 242, dtype: float64

# %% [markdown]
# #

# %%
# Adding index and converting to dataframe

Mar_On_price_mode_res1 = pd.DataFrame(Mar_On_price_mode_res, index = Mar_On_price.index)
Mar_On_price_mode_res1
# Out:
#                        0
# date
# 1996-01-31    226.000000
# 1996-02-29   -143.139978
# 1996-03-31    151.468963
# 1996-04-30      1.400369
# 1996-05-31     73.150871
# ...                  ...
# 2015-10-31 -81688.830396
# 2015-11-30  33976.053258
# 2015-12-31  -7069.306792
# 2016-01-31  -5454.422340
# 2016-02-29 -20347.459931
#
# [242 rows x 1 columns]

# %% [markdown]
# #

# %%
# Histogram of residuals

plt.hist(Mar_On_price_mode_res1, color = 'm')
plt.title('Mar_On_price - Residual_autoarima')
plt.show()

# %% [markdown]
# #

# %%
# Squaring residuals / errors

Mar_On_price_mod_se = pow(Mar_On_price_mode_res1, 2)
Mar_On_price_mod_se
# Out:
#                        0
# date
# 1996-01-31  5.107600e+04
# 1996-02-29  2.048905e+04
# 1996-03-31  2.294285e+04
# 1996-04-30  1.961034e+00
# 1996-05-31  5.351050e+03
# ...                  ...
# 2015-10-31  6.673065e+09
# 2015-11-30  1.154372e+09
# 2015-12-31  4.997510e+07
# 2016-01-31  2.975072e+07
# 2016-02-29  4.140191e+08
#
# [242 rows x 1 columns]

# %%
# average / mean of Squaring residuals / errors

Mar_On_price_mod_mse = (Mar_On_price_mod_se.sum()) / len(Mar_On_price_mod_se)
Mar_On_price_mod_mse
# Out:
# 0    2.593785e+08
# dtype: float64

# %%
# Root of average / mean of Squaring

Mar_On_price_mod_rmse = sqrt(Mar_On_price_mod_mse)
Mar_On_price_mod_rmse
# Out:
# 16105.2313962351

# %%
plot_acf(Mar_On_price_mode_res, lags = 20);

# %%
plot_pacf(Mar_On_price_mode_res, lags = 20);

# %% [markdown]
# #

# %%
# forecasting / predicting

Mar_On_pred3 = Mar_On_price_mode.predict(steps = 19)
Mar_On_pred3
# Out:
# 2016-03-31     77435.379679
# 2016-04-30    101045.958648
# 2016-05-31    123475.177785
# 2016-06-30    144024.637390
# 2016-07-31    152669.712350
# 2016-08-31    156089.437382
# 2016-09-30    151932.666328
# 2016-10-31    147810.948300
# 2016-11-30    142219.045720
# 2016-12-31    139808.070678
# Freq: M, dtype: float64

# %%
# Plot actual and forecast

plt.plot(Mar_On_price, color = 'm')
plt.plot(Mar_On_pred3, color = 'g')
plt.legend(['Actual', 'Forecast - ExponentialSmoothing'], bbox_to_anchor = (1, 1), loc = 4)
plt.show()
